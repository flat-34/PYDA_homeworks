# %%
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.linear_model import LinearRegression

# %%
# Создаём сэмпл
n_samples = 1000

age_owner = np.random.choice(90, n_samples) + 21
length = np.random.choice(120, n_samples) + 15
width = np.random.choice(80, n_samples) + 10

price = length * width * 100 + 126

data = pd.DataFrame({'age_owner': age_owner, 'length': length, 'width': width, 'price': price})
data.head(5)
# Out:
#    age_owner  length  width   price
# 0         93     128     48  614526
# 1         95     102     57  581526
# 2         40      54     69  372726
# 3         37      92     68  625726
# 4         50     124     53  657326

# %%
sns.pairplot(data)

# %%
from sklearn.metrics import mean_absolute_error

X = data[['age_owner', 'length', 'width']]
y = data['price']
reg = LinearRegression().fit(X, y)
print('Weights: {}'.format(reg.coef_))
print('Bias: {}'.format(reg.intercept_))

pred_values = reg.predict(data[['age_owner', 'length', 'width']])
print('Error: {}'.format(mean_absolute_error(pred_values, y)))
# Out:
# Weights: [ 167.26453672 4890.88638921 7601.6324044 ]
# Bias: -383267.2484349063
# Error: 61334.797961026

# %%
y.median() ### медеанная ошибка
# Out:
# 300626.0

# %%
X = data[['length', 'width']]
y = data['price']
reg = LinearRegression().fit(X, y)
print('Weights: {}'.format(reg.coef_))
print('Bias: {}'.format(reg.intercept_))

pred_values = reg.predict(data[['length', 'width']])
print('Error: {}'.format(mean_absolute_error(pred_values, y)))
# Out:
# Weights: [4892.80079666 7602.24522258]
# Bias: -372639.4733363174
# Error: 61230.101007742676

# %%
# Создаем новый признак
data['mult'] = data['length'] * data['width']
data.head(5)
# Out:
#    age_owner  length  width   price  mult
# 0         93     128     48  614526  6144
# 1         95     102     57  581526  5814
# 2         40      54     69  372726  3726
# 3         37      92     68  625726  6256
# 4         50     124     53  657326  6572

# %%
sns.pairplot(data)

# %%
X = data[['mult']]
y = data['price']
reg = LinearRegression().fit(X, y)
print('Weights: {}'.format(reg.coef_))
print('Bias: {}'.format(reg.intercept_))

pred_values = reg.predict(data[['mult']])
print('Error: {}'.format(mean_absolute_error(pred_values, y)))
# Out:
# Weights: [100.]
# Bias: 126.00000000005821
# Error: 1.8681021174415945e-11
